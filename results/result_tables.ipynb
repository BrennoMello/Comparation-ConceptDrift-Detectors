# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
def avg_last_execution(files_path, drift_detector, generator):
    
    results = []
    for file in files_path:
        #print(file)
        df = pd.read_csv(file)
        results.append(df.iloc[-1]['classifications correct (percent)'])
        #print(df.iloc[-1]['classifications correct (percent)'])
    
    tuple_results = tuple([np.mean(results), np.std(results), drift_detector, generator])
   
    #print(f'avg of all last execution: {np.mean(median)}')
    return tuple_results

# %%
drift_detectors_params = [
                              {"id": "DDM", "drift_name": "DDM", "params": ""},    \
                              {"id": "EDDM", "drift_name": "EDDM", "params": ""},   \
                              {"id": "ADWIN", "drift_name": "ADWINChangeDetector", "params": ""},  \
                              {"id": "ECDD", "drift_name": "EWMAChartDM", "params": ""},   \
                              {"id": "STEPD", "drift_name": "STEPD", "params": ""},  \
                              {"id": "SeqDrift2", "drift_name": "SeqDrift2ChangeDetector", "params": ""},  \
                              {"id": "SEED", "drift_name": "SEEDChangeDetector", "params": ""},   \
                              {"id": "HDDM_A_Test", "drift_name": "HDDM_A_Test", "params": ""},  \
                              {"id": "HDDM_W_Test", "drift_name": "HDDM_W_Test", "params": ""},  \
                              #{"id": "FHDDM", "drift_name": "FHDDM", "params": ""},  \
                              #{"id": "FTDD", "drift_name": "FTDD", "params": ""},   \
                              {"id": "RDDM_30", "drift_name": "RDDM", "params": "-n 30 -w 2 -o 3"}, \
                              {"id": "RDDM","drift_name": "RDDM", "params": ""},   \
                              #{"id": "WSTD","drift_name": "WSTD", "params": ""}
                        ]

# %% [markdown]
# ## Table Abrupt NaiveBayes 10K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 10000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}



df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          65.850667  65.881000  66.131333  65.140667    67.370333  \
# AGRAW2          86.090333  85.320667  85.579333  83.945000    86.900000
# LED             74.799000  74.799000  69.895333  74.752667    74.768000
# MIXED           90.009667  90.240667  89.451000  89.284000    90.871000
# RANDOM_RBF      91.631000  91.631000  87.111667  91.620667    91.631000
# SINE            88.195667  85.708333  88.205667  87.615667    88.638000
# WAVEFORM        80.289000  80.289000  78.770333  80.053667    80.280667
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            67.579667  67.824000  66.942333  66.342000  67.127667  \
# AGRAW2            87.019000  86.267333  85.672667  86.108333  87.100667
# LED               73.824000  74.799000  73.567333  56.613000  68.726000
# MIXED             90.867333  90.713667  90.353333  89.619667  90.873333
# RANDOM_RBF        91.631000  91.631000  91.631000  71.109333  90.480667
# SINE              88.813333  88.662333  88.210667  87.773000  88.814000
# WAVEFORM          80.268000  80.251667  80.289000  80.225000  80.037667
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          65.325667
# AGRAW2          83.690333
# LED             63.457000
# MIXED           83.803667
# RANDOM_RBF      78.882000
# SINE            82.956000
# WAVEFORM        80.285333

# %% [markdown]
# ## Table Abrupt NaiveBayes 20K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 20000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          68.598167  67.612500  66.596833  66.416333    69.048167  \
# AGRAW2          87.566500  86.917500  86.509500  85.274500    87.782333
# LED             74.605000  74.605000  69.414000  74.583833    74.605000
# MIXED           91.023000  90.336000  89.575833  90.099500    91.312333
# RANDOM_RBF      92.346000  92.346000  87.242667  92.339667    92.346000
# SINE            89.003000  85.031667  88.474500  88.077500    89.196333
# WAVEFORM        80.334667  80.334667  78.922000  80.209000    80.329333
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            68.534167  68.999167  68.613833  68.160333  68.549000  \
# AGRAW2            87.823833  87.811667  87.152833  87.392167  88.033667
# LED               72.567833  74.605000  73.883000  56.772500  70.533167
# MIXED             91.402667  91.250167  90.994000  90.502333  91.162333
# RANDOM_RBF        92.346000  92.346000  92.346000  70.763000  91.206500
# SINE              89.295167  89.093833  88.758333  88.609833  89.267833
# WAVEFORM          80.326500  80.343667  80.332667  80.308333  80.136333
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          67.701667
# AGRAW2          86.200833
# LED             65.495333
# MIXED           87.847833
# RANDOM_RBF      82.180000
# SINE            86.324833
# WAVEFORM        80.330500

# %% [markdown]
# ## Table Abrupt NaiveBayes 50K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 50000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          69.832733  67.762933  66.986667  67.363933    69.826733  \
# AGRAW2          88.541867  87.858067  86.746667  85.987200    88.516333
# LED             74.344800  74.344800  69.096733  74.338867    74.202200
# MIXED           91.656667  90.684333  89.902867  90.014467    91.715267
# RANDOM_RBF      93.043400  93.043400  87.345600  93.040667    93.043400
# SINE            89.355200  85.140933  88.432400  88.041667    89.354467
# WAVEFORM        80.400000  80.400000  79.140333  80.373800    80.399400
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            69.093400  69.865333  69.616667  69.264333  69.302067  \
# AGRAW2            88.442867  88.502600  88.153600  88.375533  88.387400
# LED               72.209800  74.254067  73.945200  57.747267  70.600933
# MIXED             91.804933  91.654800  91.486467  91.473667  91.506200
# RANDOM_RBF        93.043400  92.986933  93.012533  70.922533  91.528933
# SINE              89.469400  89.280200  89.057800  89.195600  89.320600
# WAVEFORM          80.350533  80.393467  80.395800  80.385333  80.243533
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          69.602267
# AGRAW2          87.946000
# LED             71.156200
# MIXED           90.367133
# RANDOM_RBF      87.913133
# SINE            88.250600
# WAVEFORM        80.398600

# %% [markdown]
# ## Table Abrupt NaiveBayes 100K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 100000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          70.278767  67.867567  67.061267  67.948233    70.276767  \
# AGRAW2          88.906433  87.549600  86.757833  86.250233    88.848500
# LED             74.317467  74.317467  69.263133  74.312500    74.218600
# MIXED           91.866600  90.608300  89.855033  89.740033    91.844700
# RANDOM_RBF      93.263467  93.263467  87.518900  93.262367    93.263467
# SINE            89.404600  82.818367  88.408200  88.050433    89.316400
# WAVEFORM        80.417600  80.419733  79.177133  80.412033    80.418733
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            69.400200  70.274633  69.959333  69.752333  69.564033  \
# AGRAW2            88.707867  88.814200  88.585867  88.795200  88.503233
# LED               72.387833  74.116300  73.984067  58.770433  70.074000
# MIXED             91.942500  91.825433  91.712400  91.743000  91.573000
# RANDOM_RBF        93.263467  93.038367  93.086333  70.933400  91.397233
# SINE              89.462000  89.373467  89.190467  89.278167  89.317767
# WAVEFORM          80.394300  80.428567  80.415933  80.398100  80.299533
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          70.212767
# AGRAW2          88.613800
# LED             72.735100
# MIXED           91.234167
# RANDOM_RBF      89.782700
# SINE            88.846667
# WAVEFORM        80.418933

# %% [markdown]
# ## Table Abrupt NaiveBayes 500K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 500000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector     ADWIN       DDM      ECDD      EDDM  HDDM_A_Test
# generator
# AGRAW1          70.69068  68.11760  67.09644  68.37030     70.61626  \
# AGRAW2          89.34564  88.60918  86.84728  86.68052     89.29722
# LED             74.07494  74.10654  69.23864  74.10590     74.00964
# MIXED           92.04850  90.45936  89.95416  90.66508     92.01242
# RANDOM_RBF      93.50438  93.50438  87.58970  93.50438     93.50438
# SINE            89.40398  82.27622  88.44446  84.53798     89.34066
# WAVEFORM        80.44634  80.44634  79.22972  80.44340     80.44652
#
# drift_detector  HDDM_W_Test      RDDM   RDDM_30      SEED     STEPD  SeqDrift2
# generator
# AGRAW1             69.58850  70.62170  70.33906  70.41014  69.69536   70.66708
# AGRAW2             89.02072  89.23788  89.11070  89.25210  88.66292   89.28378
# LED                72.50628  73.81776  73.84808  65.13190  70.12876   73.82534
# MIXED              92.06362  92.00830  91.97122  92.00466  91.63010   91.92460
# RANDOM_RBF         93.50438  93.16564  93.26718  70.94598  91.22270   92.95950
# SINE               89.41134  89.43522  89.30196  89.36210  89.38952   89.30290
# WAVEFORM           80.39514  80.44718  80.45112  80.43862  80.29862   80.44634

# %% [markdown]
# ## Table Abrupt NaiveBayes 1M

# %%
classificator = "bayes.NaiveBayes"
drift_size = 1000000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                     "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

# dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
#                     "abrupt_sine": "SINE"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector     ADWIN       DDM      ECDD      EDDM  HDDM_A_Test
# generator
# AGRAW1          70.75968  68.70482  67.09935  68.47945     70.68788  \
# AGRAW2          89.39134  88.21051  86.82117  86.75809     89.34224
# LED             74.06937  74.06937  69.27354  74.06907     73.99151
# MIXED           92.08354  90.20928  89.96825  87.56309     92.06546
# RANDOM_RBF      93.38604  93.36319  87.49730  93.37931     93.37377
# SINE            89.45361  81.30600  88.45821  86.66229     89.40483
# WAVEFORM        80.45072  80.45039  79.21103  80.44879     80.45504
#
# drift_detector  HDDM_W_Test      RDDM   RDDM_30      SEED     STEPD  SeqDrift2
# generator
# AGRAW1             69.65189  70.70616  70.46495  70.51735  69.77137   70.74140
# AGRAW2             89.02198  89.26711  89.14965  89.30240  88.65120   89.35881
# LED                72.53909  73.86471  73.87173  63.29537  70.09169   73.89805
# MIXED              92.09128  92.03799  92.00401  92.04781  91.65645   92.02166
# RANDOM_RBF         93.37711  93.05767  93.18186  70.81748  91.33817   92.97510
# SINE               89.45481  89.50843  89.33680  89.41922  89.39453   89.40365
# WAVEFORM           80.40267  80.45307  80.45214  80.44758  80.28985   80.45206

# %% [markdown]
# ## Table Abrupt NaiveBayes 2M

# %%
classificator = "bayes.NaiveBayes"
drift_size = 2000000
type_drift = "Abrupt"

dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                     "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

# dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
#                     "abrupt_sine": "SINE"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          70.800620  68.106905  67.106550  68.506845    70.716230  \
# AGRAW2          89.428305  88.106615  86.825790  86.827665    89.384785
# LED             74.066020  74.066020  69.330835  74.065805    73.977430
# MIXED           92.062560  90.181935  89.962840  88.914010    92.040060
# RANDOM_RBF      93.327385  93.297570  87.483745  93.289145    93.286555
# SINE            89.475315  84.916475  88.460100  86.461175    89.453020
# WAVEFORM        80.478750  80.478475  79.232165  80.478065    80.480700
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            69.686825  70.705625  70.625170  70.575740  69.769590  \
# AGRAW2            89.045310  89.291510  89.237745  89.340580  88.659815
# LED               72.546540  73.888980  73.971410  64.026195  70.175920
# MIXED             92.066730  92.017130  91.998775  92.036280  91.646705
# RANDOM_RBF        93.285980  92.957365  93.059510  70.901160  91.328295
# SINE              89.476605  89.535310  89.398410  89.457130  89.417235
# WAVEFORM          80.441895  80.480410  80.483880  80.479080  80.331135
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          70.792250
# AGRAW2          89.409900
# LED             73.778425
# MIXED           92.031740
# RANDOM_RBF      92.928290
# SINE            89.450445
# WAVEFORM        80.478610

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 10K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 10000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          67.071667  66.438333  66.066333  65.625333    68.189000  \
# AGRAW2          85.992667  85.056667  85.855000  83.799000    86.867667
# LED             74.795000  74.795000  69.841000  74.748000    74.764000
# MIXED           89.957667  90.300667  89.407667  89.273000    90.824333
# RANDOM_RBF      91.625333  91.625333  87.222333  91.625333    91.625333
# SINE            89.374333  89.208667  88.126667  87.645667    90.080000
# WAVEFORM        79.895000  79.906333  78.748000  79.738333    79.931000
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            67.962667  68.236667  67.475000  65.893333  67.004667  \
# AGRAW2            86.980000  86.664667  85.759000  85.896333  86.872333
# LED               73.813667  74.795000  73.563333  55.713667  67.918000
# MIXED             90.854000  90.674333  90.344000  89.514333  90.795667
# RANDOM_RBF        91.625333  91.625333  91.625333  70.032000  89.992667
# SINE              90.099667  89.664000  89.544667  88.713000  89.677667
# WAVEFORM          80.008333  79.955000  79.906333  79.910667  79.953333
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          65.986667
# AGRAW2          83.642000
# LED             62.367667
# MIXED           83.753000
# RANDOM_RBF      78.096667
# SINE            84.125000
# WAVEFORM        79.894000

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 20K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 20000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          72.035500  70.840500  67.003500  68.575667    72.445333  \
# AGRAW2          87.656333  86.896000  86.299333  85.014833    88.043500
# LED             74.603000  74.603000  69.368500  74.581500    74.603000
# MIXED           90.405667  88.860167  89.538500  89.557500    90.460167
# RANDOM_RBF      92.343167  92.343167  87.206167  92.343167    92.343167
# SINE            91.272500  90.575333  88.608500  88.867500    91.585333
# WAVEFORM        79.782333  79.828833  78.901833  79.718833    79.868667
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            71.107333  72.266000  72.119333  67.664000  68.927833  \
# AGRAW2            88.078500  87.771167  87.096500  87.136167  87.979833
# LED               72.547667  74.603000  73.880167  56.107000  69.743000
# MIXED             90.821333  90.864667  90.630500  90.231167  90.871667
# RANDOM_RBF        92.343167  92.343167  92.343167  70.413333  91.048167
# SINE              91.609000  91.045833  91.185333  89.809000  90.827000
# WAVEFORM          80.109500  80.043833  79.949333  79.826167  80.074667
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          67.967000
# AGRAW2          86.340833
# LED             65.202333
# MIXED           87.929000
# RANDOM_RBF      80.400000
# SINE            88.481167
# WAVEFORM        79.758500

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 50K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 50000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          77.333200  76.497800  67.975533  72.563800    77.499667  \
# AGRAW2          90.298400  89.944800  86.535800  87.668467    90.323400
# LED             73.941000  73.854800  69.083933  73.655133    73.898667
# MIXED           92.133867  91.655000  89.856333  90.488600    92.202467
# RANDOM_RBF      92.165067  92.722667  87.468933  93.805067    92.333600
# SINE            93.178467  92.749933  88.684733  90.244867    93.285933
# WAVEFORM        80.043667  80.076667  79.124733  80.052867    80.094333
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            75.528533  77.335867  77.291400  68.507267  70.562467  \
# AGRAW2            89.575867  90.160400  90.007933  87.930600  89.087000
# LED               72.191067  73.941467  73.561933  57.550067  69.929733
# MIXED             92.242667  91.691800  91.886867  91.020800  91.200533
# RANDOM_RBF        92.354133  92.327867  92.343067  69.684133  91.133000
# SINE              93.305333  92.821800  93.005467  90.503933  92.110133
# WAVEFORM          80.132000  80.198667  80.083067  79.959133  80.208400
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          71.563133
# AGRAW2          88.921733
# LED             69.743200
# MIXED           90.640600
# RANDOM_RBF      83.648800
# SINE            91.977133
# WAVEFORM        80.067933

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 100K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 100000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}



df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          80.374733  80.235300  69.405300  73.715667    80.140367  \
# AGRAW2          92.197200  91.987767  86.562167  89.972800    92.076567
# LED             73.863300  73.677733  69.228400  73.807267    73.830933
# MIXED           93.078067  92.867300  89.791600  91.481933    93.151567
# RANDOM_RBF      92.302433  93.386667  87.563033  94.810833    92.657800
# SINE            94.178933  93.918767  88.731333  91.913433    94.216600
# WAVEFORM        81.364533  81.329633  79.164067  81.130867    81.024633
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            77.733167  80.134333  80.284467  68.764067  71.730033  \
# AGRAW2            90.886700  92.049067  91.987567  88.164067  90.066000
# LED               72.370667  73.853233  73.576200  57.634367  69.771533
# MIXED             93.201600  92.528767  92.950800  91.395100  91.252800
# RANDOM_RBF        92.464000  92.487533  92.610667  69.981800  91.210600
# SINE              94.260567  93.969567  94.019000  90.737100  92.738800
# WAVEFORM          80.144167  80.396300  80.466733  79.915333  80.258267
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          73.302467
# AGRAW2          90.567933
# LED             70.916767
# MIXED           92.453133
# RANDOM_RBF      83.637533
# SINE            93.553667
# WAVEFORM        81.357767

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 500K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 500000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}



df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector     ADWIN       DDM      ECDD      EDDM  HDDM_A_Test
# generator
# AGRAW1          84.65794  84.36160  69.94126  80.99544     84.13120  \
# AGRAW2          94.94620  94.84970  86.61738  93.42858     94.87234
# LED             73.62642  73.81264  69.21604  74.00762     73.59590
# MIXED           94.92076  94.79206  89.90134  93.69658     94.93008
# RANDOM_RBF      92.22386  95.20104  87.58578  95.86984     93.45694
# SINE            96.82722  96.69294  88.73640  95.61464     96.82214
# WAVEFORM        83.36834  83.38118  79.22346  83.29200     82.70286
#
# drift_detector  HDDM_W_Test      RDDM   RDDM_30      SEED     STEPD  SeqDrift2
# generator
# AGRAW1             80.53794  83.44914  83.98706  69.08398  73.43544   77.02490
# AGRAW2             94.20762  94.22054  94.51074  88.48504  91.45564   92.56522
# LED                72.49172  73.65604  73.45618  58.20198  69.83330   71.22636
# MIXED              94.93412  94.22232  94.39082  91.92484  91.50580   94.75488
# RANDOM_RBF         92.44436  92.43906  92.54838  69.93040  91.08914   84.79676
# SINE               96.86296  96.10504  96.32446  90.96796  93.52014   96.56292
# WAVEFORM           80.18652  80.34068  81.12668  79.85190  80.24798   83.32362

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 1M

# %%
classificator = "trees.HoeffdingTree"
drift_size = 1000000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

# dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
#                     "abrupt_sine": "SINE"}

df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector     ADWIN       DDM      ECDD      EDDM  HDDM_A_Test
# generator
# AGRAW1          85.62021  85.61276  70.03307  81.91679     85.57248  \
# AGRAW2          95.59142  95.51853  86.60209  94.30087     95.42110
# LED             73.63478  74.00479  69.25716  74.08841     73.62416
# MIXED           95.97479  95.89326  89.92398  94.96484     95.97295
# RANDOM_RBF      92.22266  96.07724  87.49917  96.58256     93.89460
# SINE            97.74146  97.63867  88.74262  96.98312     97.76433
# WAVEFORM        83.92729  83.97001  79.20109  83.91260     83.34960
#
# drift_detector  HDDM_W_Test      RDDM   RDDM_30      SEED     STEPD  SeqDrift2
# generator
# AGRAW1             81.36807  84.00029  84.52702  69.08668  73.33016   77.51459
# AGRAW2             95.18665  94.51155  94.64106  88.60867  91.95465   93.07200
# LED                72.52443  73.65149  73.47984  58.93002  69.77890   71.30066
# MIXED              95.99016  94.42605  94.85907  92.05342  91.48592   95.91115
# RANDOM_RBF         92.43692  92.45066  92.54844  69.84096  91.19455   85.19530
# SINE               97.73487  96.45150  96.81352  91.00748  93.74676   97.58569
# WAVEFORM           80.15868  80.46711  81.11610  79.97168  80.25084   83.88854

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 2M

# %%
classificator = "trees.HoeffdingTree"
drift_size = 2000000
type_drift = "Abrupt"

dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

# dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
#                     "abrupt_sine": "SINE"}

df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          87.263175  87.437225  70.178815  81.925405    86.114650  \
# AGRAW2          96.006570  95.986345  86.614550  94.845660    95.910810
# LED             73.662790  74.083780  69.319845  74.122310    73.663315
# MIXED           96.895930  96.855575  89.921090  96.129310    96.918915
# RANDOM_RBF      92.170880  97.199615  87.476310  97.388380    94.939225
# SINE            98.492640  98.443195  88.756350  98.054965    98.480485
# WAVEFORM        84.347380  84.402535  79.219325  84.376820    83.636590
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            81.833465  84.766265  85.045105  69.195335  73.593530  \
# AGRAW2            95.838310  94.557040  94.868850  88.545685  91.848165
# LED               72.532185  73.687170  73.662320  58.801090  69.904645
# MIXED             96.908715  94.431320  95.027265  92.094960  91.480195
# RANDOM_RBF        92.371390  92.386380  92.519995  69.898990  91.197080
# SINE              98.483730  96.643360  96.946620  90.994725  93.894250
# WAVEFORM          80.186790  80.256690  81.146785  79.968060  80.292750
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          78.423505
# AGRAW2          93.611165
# LED             70.919985
# MIXED           96.876045
# RANDOM_RBF      85.471620
# SINE            98.412360
# WAVEFORM        84.159225

# %% [markdown]
# ## Table Gradual NaiveBayes 10K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 10000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          64.725333  65.521333  64.871667  64.390000    66.103000  \
# AGRAW2          82.677000  82.552000  81.325667  81.200667    82.975333
# LED             74.805333  74.805333  69.791667  74.758333    74.739000
# MIXED           85.379667  84.989667  84.535000  85.373000    84.868667
# RANDOM_RBF      91.634333  91.634333  87.037333  91.621667    91.634333
# SINE            84.711333  84.387333  83.989667  84.516667    84.446333
# WAVEFORM        80.292000  80.292000  78.745667  80.010667    80.258667
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            66.310667  66.551667  65.250000  65.201000  65.370667  \
# AGRAW2            83.193000  83.618667  83.023000  81.807333  82.771333
# LED               73.696000  74.805333  74.805333  56.743333  68.428667
# MIXED             85.271667  85.218000  85.244000  84.102000  84.667333
# RANDOM_RBF        91.634333  91.634333  91.634333  71.096000  90.492333
# SINE              84.677333  84.600667  84.662333  83.301667  83.977333
# WAVEFORM          80.241667  80.272667  80.292000  80.276000  80.059333
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          64.374333
# AGRAW2          79.996000
# LED             65.802667
# MIXED           84.401333
# RANDOM_RBF      80.579333
# SINE            83.400000
# WAVEFORM        80.288333

# %% [markdown]
# ## Table Gradual NaiveBayes 20K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 20000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}



df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          67.724167  67.407500  65.831667  65.754333    68.155500  \
# AGRAW2          85.517833  85.709833  83.860333  84.554500    85.845167
# LED             74.613167  74.613167  68.918667  74.594500    74.592000
# MIXED           87.842667  87.678333  86.528833  87.929333    87.612667
# RANDOM_RBF      92.353833  92.353833  87.519167  92.348333    92.353833
# SINE            86.729000  86.766500  85.961667  86.610333    86.754000
# WAVEFORM        80.340333  80.340333  78.929500  80.212667    80.331500
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            67.655333  68.267333  67.803000  67.343833  67.580833  \
# AGRAW2            85.624167  85.983000  85.733667  84.899833  85.399333
# LED               72.939833  74.613167  74.613167  56.982500  69.917333
# MIXED             87.864833  88.004167  87.952000  86.785667  87.150667
# RANDOM_RBF        92.353833  92.353833  92.353833  70.914167  90.944500
# SINE              86.697000  86.848333  86.846667  85.494000  85.919833
# WAVEFORM          80.319167  80.346667  80.343333  80.317667  80.156167
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          66.488333
# AGRAW2          84.231000
# LED             68.692167
# MIXED           87.520500
# RANDOM_RBF      83.409500
# SINE            85.969500
# WAVEFORM        80.335167

# %% [markdown]
# ## Table Gradual NaiveBayes 50K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 50000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          69.549533  68.255800  66.723067  67.145667    69.618000  \
# AGRAW2          87.770400  87.440400  85.762400  85.966667    87.560667
# LED             74.342000  74.342000  69.143867  74.335867    74.199800
# MIXED           90.588133  90.563400  88.868533  90.274000    90.568467
# RANDOM_RBF      93.045267  93.045267  87.357867  93.042600    93.045267
# SINE            88.720467  88.801800  87.629933  88.099800    88.847400
# WAVEFORM        80.399533  80.399533  79.150000  80.376267    80.393467
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            68.841733  69.642067  69.054533  68.909733  68.949000  \
# AGRAW2            87.579467  87.860933  87.573400  87.503867  87.429867
# LED               72.212800  74.255200  74.301867  57.157800  70.459533
# MIXED             90.563267  90.594867  90.583533  90.235200  90.127600
# RANDOM_RBF        93.045267  92.978400  93.026267  70.871667  91.228467
# SINE              88.848933  88.878067  88.848667  88.104933  88.260133
# WAVEFORM          80.343867  80.396067  80.396600  80.389333  80.235200
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          69.409467
# AGRAW2          87.404800
# LED             71.422667
# MIXED           90.469733
# RANDOM_RBF      87.987333
# SINE            88.382933
# WAVEFORM        80.398200

# %% [markdown]
# ## Table Gradual NaiveBayes 100K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 100000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          70.163167  68.424633  66.918000  67.892333    70.169800  \
# AGRAW2          88.492333  87.983400  86.328300  86.163767    88.472233
# LED             74.320567  74.320567  69.217633  74.316033    74.238867
# MIXED           91.334467  91.279200  89.355700  90.636567    91.312067
# RANDOM_RBF      93.263000  93.263000  87.474500  93.261967    93.263000
# SINE            89.122967  89.008833  88.001333  88.177567    89.212533
# WAVEFORM        80.416700  80.417333  79.173500  80.409467    80.416167
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            69.254300  70.186233  69.915267  69.614467  69.451900  \
# AGRAW2            88.219000  88.487333  88.341167  88.343500  87.873200
# LED               72.343000  74.117367  74.150033  59.636800  70.203800
# MIXED             91.339133  91.353433  91.340500  91.144200  90.933233
# RANDOM_RBF        93.263000  93.080733  93.095600  70.917333  91.426633
# SINE              89.233733  89.255167  89.186433  88.784000  88.806700
# WAVEFORM          80.389833  80.420300  80.417867  80.404133  80.305800
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          70.104933
# AGRAW2          88.332833
# LED             73.223900
# MIXED           91.285567
# RANDOM_RBF      90.589167
# SINE            88.924067
# WAVEFORM        80.416367

# %% [markdown]
# ## Table Gradual NaiveBayes 500K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 500000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                   "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector     ADWIN       DDM      ECDD      EDDM  HDDM_A_Test
# generator
# AGRAW1          70.66098  68.96492  67.07866  68.35260     70.56590  \
# AGRAW2          89.24634  88.82542  86.76880  86.70834     89.20514
# LED             74.08926  74.10630  69.23164  74.10534     74.00802
# MIXED           91.93446  91.86916  89.85598  90.67902     91.94012
# RANDOM_RBF      93.50422  93.50422  87.62586  93.50422     93.50422
# SINE            89.35590  86.31444  88.35624  87.02468     89.33942
# WAVEFORM        80.44566  80.44566  79.22954  80.44282     80.44598
#
# drift_detector  HDDM_W_Test      RDDM   RDDM_30      SEED     STEPD  SeqDrift2
# generator
# AGRAW1             69.56402  70.58288  70.44708  70.39294  69.68004   70.64066
# AGRAW2             88.89716  89.13418  89.02848  89.15866  88.54456   89.24240
# LED                72.51826  73.85594  73.99104  63.69346  70.11282   73.85302
# MIXED              91.93290  91.90612  91.89308  91.88804  91.51016   91.92122
# RANDOM_RBF         93.50422  93.13464  93.27348  70.99216  91.23318   92.79032
# SINE               89.37844  89.40900  89.23072  89.25422  89.28778   89.30848
# WAVEFORM           80.39456  80.44254  80.45022  80.44336  80.29806   80.44634

# %% [markdown]
# ## Table Gradual NaiveBayes 1M

# %%
classificator = "bayes.NaiveBayes"
drift_size = 1000000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                   "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector     ADWIN       DDM      ECDD      EDDM  HDDM_A_Test
# generator
# AGRAW1          70.74243  68.83349  67.08299  68.46260     70.67991  \
# AGRAW2          89.33771  87.93036  86.77348  86.73244     89.25954
# LED             74.06871  74.06871  69.28507  74.06822     73.99063
# MIXED           92.02727  91.87631  89.92086  88.65357     92.02656
# RANDOM_RBF      93.39483  93.36214  87.49374  93.37940     93.37348
# SINE            89.43297  82.98712  88.41546  84.47796     89.40783
# WAVEFORM        80.45055  80.45025  79.20939  80.44879     80.45497
#
# drift_detector  HDDM_W_Test      RDDM   RDDM_30      SEED     STEPD  SeqDrift2
# generator
# AGRAW1             69.63662  70.63373  70.49782  70.49006  69.74864   70.72666
# AGRAW2             88.94647  89.21247  89.12166  89.24588  88.59277   89.34100
# LED                72.53204  73.86816  73.99665  63.40762  70.09986   73.92408
# MIXED              92.02687  91.98133  91.98167  91.99255  91.58758   92.01881
# RANDOM_RBF         93.37668  93.05715  93.14393  70.93964  91.34587   92.89948
# SINE               89.45950  89.48083  89.35086  89.37810  89.33852   89.40195
# WAVEFORM           80.40339  80.44674  80.45243  80.45082  80.29248   80.45145

# %% [markdown]
# ## Table Gradual NaiveBayes 2M

# %%
classificator = "bayes.NaiveBayes"
drift_size = 2000000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                   "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          70.792350  68.406605  67.099130  68.577825    70.719375  \
# AGRAW2          89.390920  88.005240  86.803780  86.875255    89.339950
# LED             74.065775  74.065775  69.332175  74.065555    73.980505
# MIXED           92.034310  90.400195  89.935465  88.692105    92.022800
# RANDOM_RBF      93.324390  93.295855  87.482890  93.288760    93.286130
# SINE            89.474115  81.701095  88.438930  87.877640    89.457400
# WAVEFORM        80.478615  80.478340  79.231310  80.478010    80.480555
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            69.679895  70.705390  70.612475  70.559840  69.756380  \
# AGRAW2            88.993940  89.260960  89.215850  89.316485  88.637295
# LED               72.548375  73.897125  74.018390  62.066935  70.166370
# MIXED             92.032465  91.988895  91.980370  92.010980  91.613270
# RANDOM_RBF        93.285540  92.976695  93.039395  70.978240  91.329480
# SINE              89.487185  89.517860  89.389285  89.431115  89.387335
# WAVEFORM          80.441475  80.481550  80.481065  80.476800  80.331525
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          70.785895
# AGRAW2          89.393335
# LED             73.937890
# MIXED           92.030055
# RANDOM_RBF      92.868900
# SINE            89.450360
# WAVEFORM        80.479510

# %% [markdown]
# ## Table Gradual HoeffdingTree 10K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 10000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          65.483667  65.850667  64.567333  64.799333    66.188667  \
# AGRAW2          83.357333  83.500000  83.063333  81.614000    83.986667
# LED             74.801333  74.801333  69.740000  74.753667    74.735000
# MIXED           85.351333  84.817667  84.388333  85.274667    84.712667
# RANDOM_RBF      91.628667  91.628667  87.025333  91.628667    91.628667
# SINE            85.278000  84.943000  84.210333  84.794000    85.080667
# WAVEFORM        79.916333  79.918667  78.730667  79.701333    79.944000
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            66.243000  66.713333  65.723000  64.907000  65.438667  \
# AGRAW2            84.110333  84.348333  83.568000  83.231000  83.819333
# LED               73.682333  74.801333  74.801333  56.469333  68.073333
# MIXED             85.148000  85.045333  85.110667  83.975333  84.516333
# RANDOM_RBF        91.628667  91.628667  91.628667  70.020667  90.151333
# SINE              85.313333  85.170000  85.248667  83.508000  84.262000
# WAVEFORM          79.977000  79.950333  79.913333  79.957000  79.956333
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          64.826667
# AGRAW2          82.611667
# LED             64.491333
# MIXED           84.200000
# RANDOM_RBF      79.821333
# SINE            83.974667
# WAVEFORM        79.937667

# %% [markdown]
# ## Table Gradual HoeffdingTree 20K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 20000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          70.384333  70.487333  65.862833  67.903333    70.338167  \
# AGRAW2          85.978500  85.621000  84.663167  83.988333    86.226500
# LED             74.611167  74.611167  68.921667  74.592167    74.590000
# MIXED           87.174000  87.085833  86.321000  87.486333    86.998333
# RANDOM_RBF      92.351000  92.351000  87.601667  92.351000    92.351000
# SINE            88.223667  88.020167  86.157500  87.589833    88.024000
# WAVEFORM        79.660333  79.741167  78.910667  79.696500    79.781167
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            69.607500  70.954667  70.766000  66.831000  67.670833  \
# AGRAW2            86.158667  86.316667  85.576500  85.409167  86.068333
# LED               72.923500  74.611167  74.611167  56.363000  69.984500
# MIXED             87.152000  87.377167  87.288333  86.684167  86.985833
# RANDOM_RBF        92.351000  92.351000  92.351000  69.926167  90.781167
# SINE              88.133500  88.071500  88.180167  86.117833  87.027167
# WAVEFORM          80.058667  80.026833  79.915167  79.895333  80.076667
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          66.821833
# AGRAW2          85.537000
# LED             68.781833
# MIXED           87.268167
# RANDOM_RBF      82.743667
# SINE            87.651000
# WAVEFORM        79.612500

# %% [markdown]
# ## Table Gradual HoeffdingTree 50K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 50000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          76.363667  75.774467  68.280000  72.583133    76.190733  \
# AGRAW2          89.706800  89.603600  85.966933  87.586000    89.677067
# LED             73.957467  73.860467  69.145400  73.651333    73.912867
# MIXED           91.042267  91.015733  88.787467  90.470533    90.980133
# RANDOM_RBF      92.178800  92.800267  87.411400  93.800600    92.335533
# SINE            92.100467  92.110133  87.889867  90.479067    92.147733
# WAVEFORM        80.091000  80.146533  79.135200  80.039800    80.070000
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            74.362067  76.281400  75.736067  68.234333  69.969733  \
# AGRAW2            88.830000  89.703533  89.578867  87.279667  88.433333
# LED               72.194933  73.946800  73.854867  57.923933  69.754933
# MIXED             90.993200  90.897600  91.011467  89.804067  89.839867
# RANDOM_RBF        92.345933  92.402533  92.365800  69.933533  90.778200
# SINE              92.168933  91.945133  92.126000  89.417800  90.804000
# WAVEFORM          80.188933  80.173600  80.098067  79.926000  80.198600
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          71.040333
# AGRAW2          88.703533
# LED             69.631867
# MIXED           90.699467
# RANDOM_RBF      84.211200
# SINE            91.883733
# WAVEFORM        80.071333

# %% [markdown]
# ## Table Gradual HoeffdingTree 100K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 100000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          79.584433  79.528267  69.124600  74.043100    79.274633  \
# AGRAW2          91.876900  91.778167  86.334700  89.887933    91.752400
# LED             73.870733  73.676567  69.174700  73.814800    73.846133
# MIXED           92.524767  92.540567  89.265067  91.588467    92.511500
# RANDOM_RBF      92.302633  93.360733  87.486700  94.795467    92.619767
# SINE            93.628067  93.642867  88.357100  92.158633    93.631333
# WAVEFORM        81.370267  81.392533  79.160433  81.203133    81.100133
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            77.225633  79.841767  79.019233  68.655000  71.453767  \
# AGRAW2            90.557067  91.853000  91.802800  87.915733  89.882267
# LED               72.325800  73.854300  73.740333  57.860367  69.620667
# MIXED             92.569200  92.444467  92.573633  90.758533  90.721400
# RANDOM_RBF        92.473000  92.471567  92.432867  69.878067  91.267933
# SINE              93.703833  93.598867  93.686400  90.105433  92.206200
# WAVEFORM          80.163167  80.207367  80.516667  79.918433  80.258233
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          73.209700
# AGRAW2          90.513033
# LED             70.627233
# MIXED           92.424233
# RANDOM_RBF      84.250567
# SINE            93.521433
# WAVEFORM        81.383267

# %% [markdown]
# ## Table Gradual HoeffdingTree 500K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 500000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector     ADWIN       DDM      ECDD      EDDM  HDDM_A_Test
# generator
# AGRAW1          84.44918  84.71580  69.81624  80.18920     83.91736  \
# AGRAW2          94.80338  94.81180  86.56902  93.47528     94.75560
# LED             73.62640  73.81630  69.20840  74.00748     73.62034
# MIXED           94.79278  94.82198  89.79700  93.70288     94.76202
# RANDOM_RBF      92.22236  94.91124  87.60900  95.88282     92.92032
# SINE            96.59146  96.59432  88.66566  95.49306     96.49334
# WAVEFORM        83.36864  83.38246  79.22368  83.29442     82.80082
#
# drift_detector  HDDM_W_Test      RDDM   RDDM_30      SEED     STEPD  SeqDrift2
# generator
# AGRAW1             80.41358  84.34000  84.20208  68.97860  73.32046   77.09582
# AGRAW2             94.09270  94.23928  94.41580  88.48706  91.41422   92.50116
# LED                72.50442  73.66366  73.51224  57.99974  69.93952   70.91772
# MIXED              94.80734  94.05394  94.40166  91.83158  91.40654   94.71384
# RANDOM_RBF         92.44652  92.41176  92.51912  69.97752  91.07066   85.04972
# SINE               96.56588  96.15070  96.30760  90.83204  93.62930   96.54242
# WAVEFORM           80.10628  80.44332  80.97908  79.95242  80.24520   83.32302

# %% [markdown]
# ## Table Gradual HoeffdingTree 1M

# %%
classificator = "trees.HoeffdingTree"
drift_size = 1000000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector     ADWIN       DDM      ECDD      EDDM  HDDM_A_Test
# generator
# AGRAW1          84.91885  86.12775  70.05295  81.24670     84.15530  \
# AGRAW2          95.49324  95.49957  86.57704  94.31995     95.39612
# LED             73.63381  74.00573  69.26873  74.08901     73.64248
# MIXED           95.91989  95.91995  89.86778  95.05116     95.88547
# RANDOM_RBF      92.22178  96.00178  87.49465  96.58474     94.01165
# SINE            97.61321  97.60111  88.70750  96.95738     97.55654
# WAVEFORM        83.92935  83.96999  79.19933  83.91361     83.20800
#
# drift_detector  HDDM_W_Test      RDDM   RDDM_30      SEED     STEPD  SeqDrift2
# generator
# AGRAW1             81.30401  84.40842  84.90432  69.09120  73.42338   78.10496
# AGRAW2             95.15883  94.44865  94.64009  88.51612  91.96605   93.01831
# LED                72.51714  73.66634  73.61110  58.79509  69.84070   71.15876
# MIXED              95.89175  94.40478  94.83667  91.90192  91.42715   95.85491
# RANDOM_RBF         92.43187  92.46907  92.54800  69.91551  91.18919   85.26857
# SINE               97.63077  96.69601  96.94927  90.92721  93.68784   97.57755
# WAVEFORM           80.12905  80.42500  80.99642  79.93968  80.25343   83.88909

# %% [markdown]
# ## Table Gradual HoeffdingTree 2M

# %%
classificator = "trees.HoeffdingTree"
drift_size = 2000000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          87.057475  87.192915  70.175755  82.097310    86.270285  \
# AGRAW2          95.952395  95.963145  86.602045  94.859180    95.876350
# LED             73.661590  74.083775  69.321305  74.122585    73.660860
# MIXED           96.853700  96.912290  89.891040  96.146855    96.877565
# RANDOM_RBF      92.163975  97.199845  87.473655  97.387330    95.296150
# SINE            98.404450  98.415715  88.747110  98.058145    98.364365
# WAVEFORM        84.344885  84.402320  79.218410  84.377055    83.602720
#
# drift_detector  HDDM_W_Test       RDDM    RDDM_30       SEED      STEPD
# generator
# AGRAW1            81.885110  84.425550  85.242795  69.112265  73.658225  \
# AGRAW2            95.813070  94.493120  94.873650  88.531980  91.829600
# LED               72.534040  73.673540  73.815880  58.530160  69.895155
# MIXED             96.883895  94.435510  94.930150  92.009690  91.444325
# RANDOM_RBF        92.371990  92.371770  92.481740  69.980290  91.185290
# SINE              98.420605  96.641735  97.118585  90.989870  93.856145
# WAVEFORM          80.147565  80.372580  81.410295  79.983955  80.292780
#
# drift_detector  SeqDrift2
# generator
# AGRAW1          79.001935
# AGRAW2          93.585895
# LED             71.071575
# MIXED           96.837910
# RANDOM_RBF      85.575800
# SINE            98.399140
# WAVEFORM        84.170195
