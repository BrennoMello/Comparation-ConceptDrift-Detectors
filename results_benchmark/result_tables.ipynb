# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
def avg_last_execution(files_path, drift_detector, generator):
    
    results = []
    for file in files_path:
        print(file)
        df = pd.read_csv(file)
        results.append(np.mean(df['classifications correct (percent)']))
        #print(np.mean(df['classifications correct (percent)']))
    
    
    tuple_results = tuple([np.mean(results), np.std(results), drift_detector, generator])
   
    print(f'avg of all last execution: {tuple_results}')
    return tuple_results

# %%
drift_detectors_params = [
                              {"id": "DDM", "drift_name": "DDM", "params": ""},    \
                              {"id": "EDDM", "drift_name": "EDDM", "params": ""},   \
                              {"id": "ADWIN", "drift_name": "ADWINChangeDetector", "params": ""},  \
                              {"id": "ECDD", "drift_name": "EWMAChartDM", "params": ""},   \
                              {"id": "STEPD", "drift_name": "STEPD", "params": ""},  \
                              {"id": "SeqDrift2", "drift_name": "SeqDrift2ChangeDetector", "params": ""},  \
                              {"id": "SEED", "drift_name": "SEEDChangeDetector", "params": ""},   \
                              {"id": "HDDM_A_Test", "drift_name": "HDDM_A_Test", "params": ""},  \
                              {"id": "HDDM_W_Test", "drift_name": "HDDM_W_Test", "params": ""},  \
                              #{"id": "FHDDM", "drift_name": "FHDDM", "params": ""},  \
                              #{"id": "FTDD", "drift_name": "FTDD", "params": ""},   \
                              {"id": "RDDM_30", "drift_name": "RDDM", "params": "-n 30 -w 2 -o 3"}, \
                              {"id": "RDDM","drift_name": "RDDM", "params": ""},   \
                              #{"id": "WSTD","drift_name": "WSTD", "params": ""},
                              {"id": "NoChangeDetector","drift_name": "NoChangeDetectorNaive", "params": ""}
                        ]

# %% [markdown]
# ## Table Abrupt NaiveBayes 10K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 10000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
# Out:
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_6_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_9_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_7_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_13_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_10_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_8_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_19_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_14_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_3_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_12_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_16_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_5_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_29_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_15_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes_DDM_10000_21_AGRAW1_Abrupt.csv
# abrupt_agraw1/bayes.NaiveBayes
LED_Abrupt.csv
# abrupt_led/bayes.NaiveBayes_NoChangeDetector_10000_9_LED_Abrupt.csv
# abrupt_led/bayes.NaiveBayes_NoChangeDetector_10000_12_LED_Abrupt.csv
# avg of all last execution: (32.21151472245, 0.7061132869142075, 'NoChangeDetector', 'LED')
# avg of all last execution: (nan, nan, 'DDM', 'MIXED')
# avg of all last execution: (nan, nan, 'EDDM', 'MIXED')
# avg of all last execution: (nan, nan, 'ADWIN', 'MIXED')
# avg of all last execution: (nan, nan, 'ECDD', 'MIXED')
# avg of all last execution: (nan, nan, 'STEPD', 'MIXED')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'MIXED')
# avg of all last execution: (nan, nan, 'SEED', 'MIXED')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'MIXED')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'MIXED')
# avg of all last execution: (nan, nan, 'RDDM_30', 'MIXED')
# avg of all last execution: (nan, nan, 'RDDM', 'MIXED')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'MIXED')
# avg of all last execution: (nan, nan, 'DDM', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'EDDM', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'ADWIN', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'ECDD', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'STEPD', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'SEED', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'RDDM_30', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'RDDM', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'DDM', 'SINE')
# avg of all last execution: (nan, nan, 'EDDM', 'SINE')
# avg of all last execution: (nan, nan, 'ADWIN', 'SINE')
# avg of all last execution: (nan, nan, 'ECDD', 'SINE')
# avg of all last execution: (nan, nan, 'STEPD', 'SINE')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'SINE')
# avg of all last execution: (nan, nan, 'SEED', 'SINE')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'SINE')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'SINE')
# avg of all last execution: (nan, nan, 'RDDM_30', 'SINE')
# avg of all last execution: (nan, nan, 'RDDM', 'SINE')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'SINE')
# avg of all last execution: (nan, nan, 'DDM', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'EDDM', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'ADWIN', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'ECDD', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'STEPD', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'SEED', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'RDDM_30', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'RDDM', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'WAVEFORM')
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# drift_detector      ADWIN        DDM       ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          61.520393  61.508396  61.833953  60.425171    63.052920  \
# AGRAW2          78.344719  72.723150  81.001973  70.524610    80.120096
# LED             65.082685  73.664090  69.029418  73.572364    73.633297
# MIXED                 NaN        NaN        NaN        NaN          NaN
# RANDOM_RBF            NaN        NaN        NaN        NaN          NaN
# SINE                  NaN        NaN        NaN        NaN          NaN
# WAVEFORM              NaN        NaN        NaN        NaN          NaN
#
# drift_detector  HDDM_W_Test  NoChangeDetector       RDDM    RDDM_30
# generator
# AGRAW1            63.147448         55.609456  63.528796  62.467476  \
# AGRAW2            81.971179         75.414126  79.634494  73.337686
# LED               72.755097         32.211515  73.664090  73.664090
# MIXED                   NaN               NaN        NaN        NaN
# RANDOM_RBF              NaN               NaN        NaN        NaN
# SINE                    NaN               NaN        NaN        NaN
# WAVEFORM                NaN               NaN        NaN        NaN
#
# drift_detector       SEED      STEPD  SeqDrift2
# generator
# AGRAW1          62.249046  62.684256  61.249048
# AGRAW2          80.103952  81.507118  77.640262
# LED             56.178998  67.466107  62.653291
# MIXED                 NaN        NaN        NaN
# RANDOM_RBF            NaN        NaN        NaN
# SINE                  NaN        NaN        NaN
# WAVEFORM              NaN        NaN        NaN

# %% [markdown]
# ## Table Abrupt NaiveBayes 20K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 20000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt NaiveBayes 50K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 50000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt NaiveBayes 100K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 100000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt NaiveBayes 500K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 500000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt NaiveBayes 1M

# %%
classificator = "bayes.NaiveBayes"
drift_size = 1000000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                     "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt NaiveBayes 2M

# %%
classificator = "bayes.NaiveBayes"
drift_size = 2000000
type_drift = "Abrupt"

dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                     "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

# dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
#                     "abrupt_sine": "SINE"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 10K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 10000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
AGRAW2_Abrupt.csv
# abrupt_agraw2/trees.HoeffdingTree_EDDM_10000_24_AGRAW2_Abrupt.csv
# abrupt_agraw2/trees.HoeffdingTree_EDDM_10000_18_AGRAW2_Abrupt.csv
# abrupt_agraw2/trees.HoeffdingTree_EDDM_10000_1_AGRAW2_Abrupt.csv
# abrupt_agraw2/trees.HoeffdingTree_EDDM_10000_11_AGRAW2_Abrupt.csv
# abrupt_agraw2/trees.HoeffdingTree_EDDM_10000_10_AGRAW2_Abrupt.csv
# abrupt_agraw2/trees.HoeffdingTree_EDDM_10000_6_AGRAW2_Abrupt.csv
# abrupt_agraw2/trees.HoeffdingTree_EDDM_10000_25_AGRAW2_Abrupt.csv
# avg of all last execution: (69.27285553221014, 2.5722927439108934, 'EDDM', 'AGRAW2')
# avg of all last execution: (nan, nan, 'ADWIN', 'AGRAW2')
# avg of all last execution: (nan, nan, 'ECDD', 'AGRAW2')
# avg of all last execution: (nan, nan, 'STEPD', 'AGRAW2')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'AGRAW2')
# avg of all last execution: (nan, nan, 'SEED', 'AGRAW2')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'AGRAW2')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'AGRAW2')
# avg of all last execution: (nan, nan, 'RDDM_30', 'AGRAW2')
# avg of all last execution: (nan, nan, 'RDDM', 'AGRAW2')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'AGRAW2')
# avg of all last execution: (nan, nan, 'DDM', 'LED')
# avg of all last execution: (nan, nan, 'EDDM', 'LED')
# avg of all last execution: (nan, nan, 'ADWIN', 'LED')
# avg of all last execution: (nan, nan, 'ECDD', 'LED')
# avg of all last execution: (nan, nan, 'STEPD', 'LED')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'LED')
# avg of all last execution: (nan, nan, 'SEED', 'LED')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'LED')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'LED')
# avg of all last execution: (nan, nan, 'RDDM_30', 'LED')
# avg of all last execution: (nan, nan, 'RDDM', 'LED')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'LED')
# avg of all last execution: (nan, nan, 'DDM', 'MIXED')
# avg of all last execution: (nan, nan, 'EDDM', 'MIXED')
# avg of all last execution: (nan, nan, 'ADWIN', 'MIXED')
# avg of all last execution: (nan, nan, 'ECDD', 'MIXED')
# avg of all last execution: (nan, nan, 'STEPD', 'MIXED')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'MIXED')
# avg of all last execution: (nan, nan, 'SEED', 'MIXED')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'MIXED')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'MIXED')
# avg of all last execution: (nan, nan, 'RDDM_30', 'MIXED')
# avg of all last execution: (nan, nan, 'RDDM', 'MIXED')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'MIXED')
# avg of all last execution: (nan, nan, 'DDM', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'EDDM', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'ADWIN', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'ECDD', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'STEPD', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'SEED', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'RDDM_30', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'RDDM', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'RANDOM_RBF')
# avg of all last execution: (nan, nan, 'DDM', 'SINE')
# avg of all last execution: (nan, nan, 'EDDM', 'SINE')
# avg of all last execution: (nan, nan, 'ADWIN', 'SINE')
# avg of all last execution: (nan, nan, 'ECDD', 'SINE')
# avg of all last execution: (nan, nan, 'STEPD', 'SINE')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'SINE')
# avg of all last execution: (nan, nan, 'SEED', 'SINE')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'SINE')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'SINE')
# avg of all last execution: (nan, nan, 'RDDM_30', 'SINE')
# avg of all last execution: (nan, nan, 'RDDM', 'SINE')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'SINE')
# avg of all last execution: (nan, nan, 'DDM', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'EDDM', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'ADWIN', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'ECDD', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'STEPD', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'SeqDrift2', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'SEED', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'HDDM_A_Test', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'HDDM_W_Test', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'RDDM_30', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'RDDM', 'WAVEFORM')
# avg of all last execution: (nan, nan, 'NoChangeDetector', 'WAVEFORM')
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/brenno/.pyenv/versions/3.10.11/envs/ipython/lib/python3.10/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# drift_detector      ADWIN        DDM      ECDD       EDDM  HDDM_A_Test
# generator
# AGRAW1          62.404297  63.104370  63.25001  62.085295    64.353767  \
# AGRAW2                NaN  72.368226       NaN  69.272856          NaN
# LED                   NaN        NaN       NaN        NaN          NaN
# MIXED                 NaN        NaN       NaN        NaN          NaN
# RANDOM_RBF            NaN        NaN       NaN        NaN          NaN
# SINE                  NaN        NaN       NaN        NaN          NaN
# WAVEFORM              NaN        NaN       NaN        NaN          NaN
#
# drift_detector  HDDM_W_Test  NoChangeDetector       RDDM    RDDM_30
# generator
# AGRAW1            64.334721          58.21486  64.760529  63.185357  \
# AGRAW2                  NaN               NaN        NaN        NaN
# LED                     NaN               NaN        NaN        NaN
# MIXED                   NaN               NaN        NaN        NaN
# RANDOM_RBF              NaN               NaN        NaN        NaN
# SINE                    NaN               NaN        NaN        NaN
# WAVEFORM                NaN               NaN        NaN        NaN
#
# drift_detector       SEED      STEPD  SeqDrift2
# generator
# AGRAW1          63.230591  63.724003  62.866327
# AGRAW2                NaN        NaN        NaN
# LED                   NaN        NaN        NaN
# MIXED                 NaN        NaN        NaN
# RANDOM_RBF            NaN        NaN        NaN
# SINE                  NaN        NaN        NaN
# WAVEFORM              NaN        NaN        NaN

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 20K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 20000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 50K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 50000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 100K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 100000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}



df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 500K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 500000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}



df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 1M

# %%
classificator = "trees.HoeffdingTree"
drift_size = 1000000
type_drift = "Abrupt"
dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Abrupt Hoeffding Tree 2M

# %%
classificator = "trees.HoeffdingTree"
drift_size = 2000000
type_drift = "Abrupt"

dict_drift_type = {"abrupt_agraw1": "AGRAW1", "abrupt_agraw2": "AGRAW2", "abrupt_led": "LED", "abrupt_mixed": "MIXED", "abrupt_randomRBF": "RANDOM_RBF",  
                    "abrupt_sine": "SINE", "abrupt_waveform": "WAVEFORM"}

df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual NaiveBayes 10K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 10000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual NaiveBayes 20K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 20000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual NaiveBayes 50K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 50000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual NaiveBayes 100K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 100000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual NaiveBayes 500K

# %%
classificator = "bayes.NaiveBayes"
drift_size = 500000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                   "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual NaiveBayes 1M

# %%
classificator = "bayes.NaiveBayes"
drift_size = 1000000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                   "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual NaiveBayes 2M

# %%
classificator = "bayes.NaiveBayes"
drift_size = 2000000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                   "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual HoeffdingTree 10K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 10000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual HoeffdingTree 20K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 20000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual HoeffdingTree 50K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 50000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual HoeffdingTree 100K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 100000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual HoeffdingTree 500K

# %%
classificator = "trees.HoeffdingTree"
drift_size = 500000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual HoeffdingTree 1M

# %%
classificator = "trees.HoeffdingTree"
drift_size = 1000000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot

# %% [markdown]
# ## Table Gradual HoeffdingTree 2M

# %%
classificator = "trees.HoeffdingTree"
drift_size = 2000000
type_drift = "Gradual"
dict_drift_type = {"gradual_agraw1": "AGRAW1", "gradual_agraw2": "AGRAW2", "gradual_led": "LED", 
                    "gradual_mixed": "MIXED", "gradual_randomRBF": "RANDOM_RBF", "gradual_sine": "SINE", "gradual_waveform": "WAVEFORM"}


df_final_result = pd.DataFrame()
for drift_key, drift_value in dict_drift_type.items():    

    tuple_list_result = list()
    for drift in drift_detectors_params:
        files_path = glob.glob(f'{drift_key}/{classificator}_{drift["id"]}_{drift_size}_*_{drift_value}_{type_drift}.csv')
        #print(files_path)
        tuple_result = avg_last_execution(files_path, drift["id"], drift_value)
        tuple_list_result.append(tuple_result)
                          
    df_result = pd.DataFrame(tuple_list_result, columns=['avg', 'std', 'drift_detector', 'generator'])
    df_final_result = pd.concat([df_final_result, df_result])

df_result_pivot = df_final_result.reset_index().pivot(index="generator", columns="drift_detector", values="avg")
df_result_pivot
